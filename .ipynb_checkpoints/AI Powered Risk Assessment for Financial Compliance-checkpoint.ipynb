# %%
import pandas as pd
dataset = pd.read_csv("C:/Users/home/Downloads/HI-Small_Trans.csv")

# %%
dataset.shape
# Out:
# (5078345, 11)

# %%
dataset.columns
# Out:
# Index(['Timestamp', 'From Bank', 'Account', 'To Bank', 'Account.1',
#        'Amount Received', 'Receiving Currency', 'Amount Paid',
#        'Payment Currency', 'Payment Format', 'Is Laundering'],
#       dtype='object')

# %%
dataset.head(20)
# Out:
#            Timestamp  From Bank    Account  To Bank  Account.1  \
# 0   2022/09/01 00:20         10  8000EBD30       10  8000EBD30
# 1   2022/09/01 00:20       3208  8000F4580        1  8000F5340
# 2   2022/09/01 00:00       3209  8000F4670     3209  8000F4670
# 3   2022/09/01 00:02         12  8000F5030       12  8000F5030
# 4   2022/09/01 00:06         10  8000F5200       10  8000F5200
# 5   2022/09/01 00:03          1  8000F5AD0        1  8000F5AD0
# 6   2022/09/01 00:08          1  8000EBAC0        1  8000EBAC0
# 7   2022/09/01 00:16          1  8000EC1E0        1  8000EC1E0
# 8   2022/09/01 00:26         12  8000EC280     2439  8017BF800
# 9   2022/09/01 00:21          1  8000EDEC0   211050  80AEF5310
# 10  2022/09/01 00:04          1  8000F4510    11813  8011305D0
# 11  2022/09/01 00:04          1  8000F47F0        1  8000F47F0
# 12  2022/09/01 00:08          1  8000F4FE0   245335  812ED62E0
# 13  2022/09/01 00:17         10  80012FD90    36056  812ED6380
# ...

# %%
dataset.columns
# Out:
# Index(['Timestamp', 'From Bank', 'Account', 'To Bank', 'Account.1',
#        'Amount Received', 'Receiving Currency', 'Amount Paid',
#        'Payment Currency', 'Payment Format', 'Is Laundering'],
#       dtype='object')

# %%
dataset['Is Laundering'].unique()
# Out:
# array([0, 1])

# %%
dataset.dtypes
# Out:
# Timestamp              object
# From Bank               int64
# Account                object
# To Bank                 int64
# Account.1              object
# Amount Received       float64
# Receiving Currency     object
# Amount Paid           float64
# Payment Currency       object
# Payment Format         object
# Is Laundering           int64
# dtype: object
